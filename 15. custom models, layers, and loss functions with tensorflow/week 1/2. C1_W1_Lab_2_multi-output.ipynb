# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 937us/sample - loss: 221.6498 - y1_output_loss: 104.3997 - y2_output_loss: 115.6331 - y1_output_root_mean_squared_error: 10.2498 - y2_output_root_mean_squared_error: 10.7977 - val_loss: 46.0368 - val_y1_output_loss: 19.1660 - val_y2_output_loss: 25.5958 - val_y1_output_root_mean_squared_error: 4.4336 - val_y2_output_root_mean_squared_error: 5.1361
# Epoch 2/500
# 614/614 [==============================] - 0s 140us/sample - loss: 31.7432 - y1_output_loss: 11.8797 - y2_output_loss: 19.9105 - y1_output_root_mean_squared_error: 3.4473 - y2_output_root_mean_squared_error: 4.4564 - val_loss: 44.5673 - val_y1_output_loss: 18.0189 - val_y2_output_loss: 26.3698 - val_y1_output_root_mean_squared_error: 4.2671 - val_y2_output_root_mean_squared_error: 5.1341
# Epoch 3/500
# 614/614 [==============================] - 0s 147us/sample - loss: 27.5123 - y1_output_loss: 10.3874 - y2_output_loss: 17.0064 - y1_output_root_mean_squared_error: 3.2240 - y2_output_root_mean_squared_error: 4.1374 - val_loss: 27.0941 - val_y1_output_loss: 12.8123 - val_y2_output_loss: 13.5378 - val_y1_output_root_mean_squared_error: 3.6267 - val_y2_output_root_mean_squared_error: 3.7338
# Epoch 4/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.5750 - y1_output_loss: 9.3303 - y2_output_loss: 15.1878 - y1_output_root_mean_squared_error: 3.0678 - y2_output_root_mean_squared_error: 3.8940 - val_loss: 38.1483 - val_y1_output_loss: 12.0121 - val_y2_output_loss: 26.8249 - val_y1_output_root_mean_squared_error: 3.4591 - val_y2_output_root_mean_squared_error: 5.1169
# Epoch 5/500
# 614/614 [==============================] - 0s 134us/sample - loss: 21.9456 - y1_output_loss: 8.7158 - y2_output_loss: 13.3581 - y1_output_root_mean_squared_error: 2.9320 - y2_output_root_mean_squared_error: 3.6536 - val_loss: 22.5147 - val_y1_output_loss: 11.8156 - val_y2_output_loss: 10.0576 - val_y1_output_root_mean_squared_error: 3.4936 - val_y2_output_root_mean_squared_error: 3.2108
# Epoch 6/500
# 614/614 [==============================] - 0s 135us/sample - loss: 24.8642 - y1_output_loss: 9.1538 - y2_output_loss: 15.6896 - y1_output_root_mean_squared_error: 3.0166 - y2_output_root_mean_squared_error: 3.9705 - val_loss: 18.7176 - val_y1_output_loss: 8.7643 - val_y2_output_loss: 9.4819 - val_y1_output_root_mean_squared_error: 3.0004 - val_y2_output_root_mean_squared_error: 3.1169
# Epoch 7/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.3399 - y1_output_loss: 8.3228 - y2_output_loss: 14.4820 - y1_output_root_mean_squared_error: 2.8700 - y2_output_root_mean_squared_error: 3.7554 - val_loss: 46.9347 - val_y1_output_loss: 11.1954 - val_y2_output_loss: 36.2318 - val_y1_output_root_mean_squared_error: 3.3310 - val_y2_output_root_mean_squared_error: 5.9866
# Epoch 8/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.5537 - y1_output_loss: 7.9550 - y2_output_loss: 12.6000 - y1_output_root_mean_squared_error: 2.8077 - y2_output_root_mean_squared_error: 3.5596 - val_loss: 16.3409 - val_y1_output_loss: 8.1327 - val_y2_output_loss: 8.1086 - val_y1_output_root_mean_squared_error: 2.8596 - val_y2_output_root_mean_squared_error: 2.8572
# Epoch 9/500
# 614/614 [==============================] - 0s 136us/sample - loss: 19.8843 - y1_output_loss: 7.5403 - y2_output_loss: 12.1714 - y1_output_root_mean_squared_error: 2.7571 - y2_output_root_mean_squared_error: 3.5047 - val_loss: 14.7250 - val_y1_output_loss: 7.3594 - val_y2_output_loss: 7.4172 - val_y1_output_root_mean_squared_error: 2.7155 - val_y2_output_root_mean_squared_error: 2.7113
# Epoch 10/500
# 614/614 [==============================] - 0s 154us/sample - loss: 19.1888 - y1_output_loss: 7.1929 - y2_output_loss: 11.9228 - y1_output_root_mean_squared_error: 2.6910 - y2_output_root_mean_squared_error: 3.4565 - val_loss: 16.5176 - val_y1_output_loss: 7.8223 - val_y2_output_loss: 8.4736 - val_y1_output_root_mean_squared_error: 2.8155 - val_y2_output_root_mean_squared_error: 2.9310
# Epoch 11/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.7520 - y1_output_loss: 7.3060 - y2_output_loss: 11.5699 - y1_output_root_mean_squared_error: 2.6842 - y2_output_root_mean_squared_error: 3.3981 - val_loss: 40.1253 - val_y1_output_loss: 12.6119 - val_y2_output_loss: 27.5747 - val_y1_output_root_mean_squared_error: 3.5590 - val_y2_output_root_mean_squared_error: 5.2401
# Epoch 12/500
# 614/614 [==============================] - 0s 134us/sample - loss: 20.4417 - y1_output_loss: 7.2567 - y2_output_loss: 13.2522 - y1_output_root_mean_squared_error: 2.6920 - y2_output_root_mean_squared_error: 3.6325 - val_loss: 31.7361 - val_y1_output_loss: 9.4540 - val_y2_output_loss: 22.9244 - val_y1_output_root_mean_squared_error: 3.0538 - val_y2_output_root_mean_squared_error: 4.7340
# Epoch 13/500
# 614/614 [==============================] - 0s 139us/sample - loss: 17.3642 - y1_output_loss: 6.7013 - y2_output_loss: 10.5154 - y1_output_root_mean_squared_error: 2.6004 - y2_output_root_mean_squared_error: 3.2561 - val_loss: 16.5124 - val_y1_output_loss: 7.3608 - val_y2_output_loss: 9.4650 - val_y1_output_root_mean_squared_error: 2.7071 - val_y2_output_root_mean_squared_error: 3.0305
# Epoch 14/500
# 614/614 [==============================] - 0s 138us/sample - loss: 19.4995 - y1_output_loss: 7.0133 - y2_output_loss: 12.5854 - y1_output_root_mean_squared_error: 2.6469 - y2_output_root_mean_squared_error: 3.5346 - val_loss: 13.6991 - val_y1_output_loss: 6.4733 - val_y2_output_loss: 7.3160 - val_y1_output_root_mean_squared_error: 2.5597 - val_y2_output_root_mean_squared_error: 2.6734
# Epoch 15/500
# 614/614 [==============================] - 0s 132us/sample - loss: 18.4899 - y1_output_loss: 6.6552 - y2_output_loss: 12.1979 - y1_output_root_mean_squared_error: 2.5654 - y2_output_root_mean_squared_error: 3.4509 - val_loss: 162.0491 - val_y1_output_loss: 24.2113 - val_y2_output_loss: 136.0982 - val_y1_output_root_mean_squared_error: 4.9489 - val_y2_output_root_mean_squared_error: 11.7285
# Epoch 16/500
# 614/614 [==============================] - 0s 154us/sample - loss: 22.7527 - y1_output_loss: 6.5960 - y2_output_loss: 16.1974 - y1_output_root_mean_squared_error: 2.5699 - y2_output_root_mean_squared_error: 4.0185 - val_loss: 23.5134 - val_y1_output_loss: 8.9506 - val_y2_output_loss: 14.9562 - val_y1_output_root_mean_squared_error: 2.9834 - val_y2_output_root_mean_squared_error: 3.8227
# Epoch 17/500
# 614/614 [==============================] - 0s 158us/sample - loss: 15.7182 - y1_output_loss: 5.5271 - y2_output_loss: 10.1619 - y1_output_root_mean_squared_error: 2.3551 - y2_output_root_mean_squared_error: 3.1893 - val_loss: 25.0581 - val_y1_output_loss: 7.5151 - val_y2_output_loss: 18.1189 - val_y1_output_root_mean_squared_error: 2.7180 - val_y2_output_root_mean_squared_error: 4.2036
# Epoch 18/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.2140 - y1_output_loss: 5.4794 - y2_output_loss: 9.6541 - y1_output_root_mean_squared_error: 2.3498 - y2_output_root_mean_squared_error: 3.1132 - val_loss: 13.9217 - val_y1_output_loss: 5.5286 - val_y2_output_loss: 8.1955 - val_y1_output_root_mean_squared_error: 2.3662 - val_y2_output_root_mean_squared_error: 2.8849
# Epoch 19/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.9209 - y1_output_loss: 5.1454 - y2_output_loss: 8.0002 - y1_output_root_mean_squared_error: 2.2402 - y2_output_root_mean_squared_error: 2.8111 - val_loss: 14.4124 - val_y1_output_loss: 6.8813 - val_y2_output_loss: 7.2373 - val_y1_output_root_mean_squared_error: 2.6607 - val_y2_output_root_mean_squared_error: 2.7079
# Epoch 20/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.4484 - y1_output_loss: 5.0769 - y2_output_loss: 9.4655 - y1_output_root_mean_squared_error: 2.2504 - y2_output_root_mean_squared_error: 3.0634 - val_loss: 19.3504 - val_y1_output_loss: 7.1028 - val_y2_output_loss: 12.4549 - val_y1_output_root_mean_squared_error: 2.6678 - val_y2_output_root_mean_squared_error: 3.4976
# Epoch 21/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.1274 - y1_output_loss: 5.2919 - y2_output_loss: 8.7419 - y1_output_root_mean_squared_error: 2.3055 - y2_output_root_mean_squared_error: 2.9685 - val_loss: 13.0859 - val_y1_output_loss: 5.3947 - val_y2_output_loss: 7.8570 - val_y1_output_root_mean_squared_error: 2.3238 - val_y2_output_root_mean_squared_error: 2.7723
# Epoch 22/500
# 614/614 [==============================] - 0s 157us/sample - loss: 13.6377 - y1_output_loss: 4.8473 - y2_output_loss: 8.8439 - y1_output_root_mean_squared_error: 2.1975 - y2_output_root_mean_squared_error: 2.9679 - val_loss: 16.3823 - val_y1_output_loss: 5.4765 - val_y2_output_loss: 10.6288 - val_y1_output_root_mean_squared_error: 2.3443 - val_y2_output_root_mean_squared_error: 3.2995
# Epoch 23/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.7975 - y1_output_loss: 4.0965 - y2_output_loss: 6.6170 - y1_output_root_mean_squared_error: 2.0317 - y2_output_root_mean_squared_error: 2.5826 - val_loss: 9.6104 - val_y1_output_loss: 4.1329 - val_y2_output_loss: 5.6422 - val_y1_output_root_mean_squared_error: 2.0329 - val_y2_output_root_mean_squared_error: 2.3404
# Epoch 24/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.7037 - y1_output_loss: 4.3364 - y2_output_loss: 7.4882 - y1_output_root_mean_squared_error: 2.0667 - y2_output_root_mean_squared_error: 2.7262 - val_loss: 11.1610 - val_y1_output_loss: 5.4841 - val_y2_output_loss: 5.8704 - val_y1_output_root_mean_squared_error: 2.3350 - val_y2_output_root_mean_squared_error: 2.3893
# Epoch 25/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.8837 - y1_output_loss: 3.8586 - y2_output_loss: 6.9333 - y1_output_root_mean_squared_error: 1.9723 - y2_output_root_mean_squared_error: 2.6446 - val_loss: 10.3763 - val_y1_output_loss: 4.3298 - val_y2_output_loss: 5.9006 - val_y1_output_root_mean_squared_error: 2.0982 - val_y2_output_root_mean_squared_error: 2.4441
# Epoch 26/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.5388 - y1_output_loss: 4.0636 - y2_output_loss: 7.4550 - y1_output_root_mean_squared_error: 2.0248 - y2_output_root_mean_squared_error: 2.7275 - val_loss: 15.4295 - val_y1_output_loss: 4.2013 - val_y2_output_loss: 11.3404 - val_y1_output_root_mean_squared_error: 2.0553 - val_y2_output_root_mean_squared_error: 3.3474
# Epoch 27/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.5574 - y1_output_loss: 3.6066 - y2_output_loss: 5.8868 - y1_output_root_mean_squared_error: 1.9060 - y2_output_root_mean_squared_error: 2.4340 - val_loss: 17.4336 - val_y1_output_loss: 5.6041 - val_y2_output_loss: 11.8284 - val_y1_output_root_mean_squared_error: 2.3781 - val_y2_output_root_mean_squared_error: 3.4319
# Epoch 28/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.5278 - y1_output_loss: 3.6335 - y2_output_loss: 7.0784 - y1_output_root_mean_squared_error: 1.8978 - y2_output_root_mean_squared_error: 2.6317 - val_loss: 15.0288 - val_y1_output_loss: 4.5112 - val_y2_output_loss: 10.7289 - val_y1_output_root_mean_squared_error: 2.1222 - val_y2_output_root_mean_squared_error: 3.2442
# Epoch 29/500
# 614/614 [==============================] - 0s 155us/sample - loss: 11.3724 - y1_output_loss: 3.8280 - y2_output_loss: 7.5407 - y1_output_root_mean_squared_error: 1.9589 - y2_output_root_mean_squared_error: 2.7450 - val_loss: 11.0155 - val_y1_output_loss: 4.8065 - val_y2_output_loss: 5.9658 - val_y1_output_root_mean_squared_error: 2.2245 - val_y2_output_root_mean_squared_error: 2.4631
# Epoch 30/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.4411 - y1_output_loss: 3.3362 - y2_output_loss: 6.1637 - y1_output_root_mean_squared_error: 1.8300 - y2_output_root_mean_squared_error: 2.4682 - val_loss: 10.4295 - val_y1_output_loss: 4.3736 - val_y2_output_loss: 6.1092 - val_y1_output_root_mean_squared_error: 2.0890 - val_y2_output_root_mean_squared_error: 2.4628
# Epoch 31/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.1194 - y1_output_loss: 3.8935 - y2_output_loss: 7.2035 - y1_output_root_mean_squared_error: 1.9822 - y2_output_root_mean_squared_error: 2.6815 - val_loss: 30.5933 - val_y1_output_loss: 5.5234 - val_y2_output_loss: 24.8141 - val_y1_output_root_mean_squared_error: 2.3694 - val_y2_output_root_mean_squared_error: 4.9979
# Epoch 32/500
# 614/614 [==============================] - 0s 138us/sample - loss: 9.9360 - y1_output_loss: 3.2288 - y2_output_loss: 6.7346 - y1_output_root_mean_squared_error: 1.8002 - y2_output_root_mean_squared_error: 2.5875 - val_loss: 8.1267 - val_y1_output_loss: 3.3185 - val_y2_output_loss: 4.7465 - val_y1_output_root_mean_squared_error: 1.8383 - val_y2_output_root_mean_squared_error: 2.1789
# Epoch 33/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.4659 - y1_output_loss: 3.3055 - y2_output_loss: 6.0864 - y1_output_root_mean_squared_error: 1.8240 - y2_output_root_mean_squared_error: 2.4777 - val_loss: 8.0304 - val_y1_output_loss: 3.1924 - val_y2_output_loss: 4.8731 - val_y1_output_root_mean_squared_error: 1.7905 - val_y2_output_root_mean_squared_error: 2.1965
# Epoch 34/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.4627 - y1_output_loss: 2.8711 - y2_output_loss: 5.5752 - y1_output_root_mean_squared_error: 1.7000 - y2_output_root_mean_squared_error: 2.3606 - val_loss: 10.1949 - val_y1_output_loss: 3.9189 - val_y2_output_loss: 6.0805 - val_y1_output_root_mean_squared_error: 2.0049 - val_y2_output_root_mean_squared_error: 2.4850
# Epoch 35/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.9221 - y1_output_loss: 2.9464 - y2_output_loss: 6.0747 - y1_output_root_mean_squared_error: 1.7186 - y2_output_root_mean_squared_error: 2.4431 - val_loss: 38.9304 - val_y1_output_loss: 9.0522 - val_y2_output_loss: 30.0095 - val_y1_output_root_mean_squared_error: 3.0013 - val_y2_output_root_mean_squared_error: 5.4702
# Epoch 36/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.5676 - y1_output_loss: 3.5754 - y2_output_loss: 8.8743 - y1_output_root_mean_squared_error: 1.8996 - y2_output_root_mean_squared_error: 2.9932 - val_loss: 7.8960 - val_y1_output_loss: 2.7976 - val_y2_output_loss: 5.1993 - val_y1_output_root_mean_squared_error: 1.6656 - val_y2_output_root_mean_squared_error: 2.2631
# Epoch 37/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.1556 - y1_output_loss: 2.5080 - y2_output_loss: 5.7284 - y1_output_root_mean_squared_error: 1.5796 - y2_output_root_mean_squared_error: 2.3792 - val_loss: 9.0246 - val_y1_output_loss: 3.0796 - val_y2_output_loss: 6.2762 - val_y1_output_root_mean_squared_error: 1.7272 - val_y2_output_root_mean_squared_error: 2.4579
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.5045 - y1_output_loss: 2.8767 - y2_output_loss: 6.6530 - y1_output_root_mean_squared_error: 1.6818 - y2_output_root_mean_squared_error: 2.5838 - val_loss: 6.5753 - val_y1_output_loss: 2.5595 - val_y2_output_loss: 4.0282 - val_y1_output_root_mean_squared_error: 1.6058 - val_y2_output_root_mean_squared_error: 1.9992
# Epoch 39/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.5907 - y1_output_loss: 2.7629 - y2_output_loss: 5.8278 - y1_output_root_mean_squared_error: 1.6522 - y2_output_root_mean_squared_error: 2.4209 - val_loss: 11.0276 - val_y1_output_loss: 3.5156 - val_y2_output_loss: 7.1965 - val_y1_output_root_mean_squared_error: 1.9005 - val_y2_output_root_mean_squared_error: 2.7232
# Epoch 40/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.9787 - y1_output_loss: 2.5356 - y2_output_loss: 5.3747 - y1_output_root_mean_squared_error: 1.5992 - y2_output_root_mean_squared_error: 2.3284 - val_loss: 7.2054 - val_y1_output_loss: 2.5203 - val_y2_output_loss: 4.5218 - val_y1_output_root_mean_squared_error: 1.6078 - val_y2_output_root_mean_squared_error: 2.1495
# Epoch 41/500
# 614/614 [==============================] - 0s 167us/sample - loss: 8.7174 - y1_output_loss: 2.6933 - y2_output_loss: 5.9501 - y1_output_root_mean_squared_error: 1.6471 - y2_output_root_mean_squared_error: 2.4504 - val_loss: 6.8299 - val_y1_output_loss: 2.4728 - val_y2_output_loss: 4.3907 - val_y1_output_root_mean_squared_error: 1.5706 - val_y2_output_root_mean_squared_error: 2.0888
# Epoch 42/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.6151 - y1_output_loss: 2.5160 - y2_output_loss: 6.0396 - y1_output_root_mean_squared_error: 1.5898 - y2_output_root_mean_squared_error: 2.4673 - val_loss: 7.7462 - val_y1_output_loss: 3.1567 - val_y2_output_loss: 4.5603 - val_y1_output_root_mean_squared_error: 1.7788 - val_y2_output_root_mean_squared_error: 2.1406
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.5762 - y1_output_loss: 2.1046 - y2_output_loss: 4.5344 - y1_output_root_mean_squared_error: 1.4453 - y2_output_root_mean_squared_error: 2.1183 - val_loss: 7.5687 - val_y1_output_loss: 2.3552 - val_y2_output_loss: 5.1435 - val_y1_output_root_mean_squared_error: 1.5500 - val_y2_output_root_mean_squared_error: 2.2729
# Epoch 44/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.7011 - y1_output_loss: 2.6005 - y2_output_loss: 6.1423 - y1_output_root_mean_squared_error: 1.6146 - y2_output_root_mean_squared_error: 2.4686 - val_loss: 11.3633 - val_y1_output_loss: 3.2811 - val_y2_output_loss: 8.0618 - val_y1_output_root_mean_squared_error: 1.8183 - val_y2_output_root_mean_squared_error: 2.8385
# Epoch 45/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.1796 - y1_output_loss: 2.1173 - y2_output_loss: 5.1824 - y1_output_root_mean_squared_error: 1.4556 - y2_output_root_mean_squared_error: 2.2496 - val_loss: 22.2431 - val_y1_output_loss: 4.6885 - val_y2_output_loss: 16.7927 - val_y1_output_root_mean_squared_error: 2.2047 - val_y2_output_root_mean_squared_error: 4.1692
# Epoch 46/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.8339 - y1_output_loss: 1.9299 - y2_output_loss: 4.8421 - y1_output_root_mean_squared_error: 1.3953 - y2_output_root_mean_squared_error: 2.2106 - val_loss: 11.0983 - val_y1_output_loss: 3.2111 - val_y2_output_loss: 7.9125 - val_y1_output_root_mean_squared_error: 1.7938 - val_y2_output_root_mean_squared_error: 2.8073
# Epoch 47/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.3457 - y1_output_loss: 1.9133 - y2_output_loss: 4.4147 - y1_output_root_mean_squared_error: 1.3880 - y2_output_root_mean_squared_error: 2.1022 - val_loss: 12.5275 - val_y1_output_loss: 3.2603 - val_y2_output_loss: 8.9078 - val_y1_output_root_mean_squared_error: 1.8308 - val_y2_output_root_mean_squared_error: 3.0291
# Epoch 48/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.6826 - y1_output_loss: 2.0334 - y2_output_loss: 4.6562 - y1_output_root_mean_squared_error: 1.4155 - y2_output_root_mean_squared_error: 2.1631 - val_loss: 8.1629 - val_y1_output_loss: 2.8839 - val_y2_output_loss: 5.0560 - val_y1_output_root_mean_squared_error: 1.7209 - val_y2_output_root_mean_squared_error: 2.2807
# Epoch 49/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.3855 - y1_output_loss: 1.9806 - y2_output_loss: 4.3500 - y1_output_root_mean_squared_error: 1.4136 - y2_output_root_mean_squared_error: 2.0946 - val_loss: 5.9588 - val_y1_output_loss: 1.7404 - val_y2_output_loss: 4.1806 - val_y1_output_root_mean_squared_error: 1.3314 - val_y2_output_root_mean_squared_error: 2.0460
# Epoch 50/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.1328 - y1_output_loss: 1.8790 - y2_output_loss: 4.3480 - y1_output_root_mean_squared_error: 1.3568 - y2_output_root_mean_squared_error: 2.0717 - val_loss: 37.8491 - val_y1_output_loss: 10.4736 - val_y2_output_loss: 26.0575 - val_y1_output_root_mean_squared_error: 3.2960 - val_y2_output_root_mean_squared_error: 5.1947
# Epoch 51/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.8889 - y1_output_loss: 2.0604 - y2_output_loss: 5.8457 - y1_output_root_mean_squared_error: 1.4347 - y2_output_root_mean_squared_error: 2.4147 - val_loss: 14.3069 - val_y1_output_loss: 4.8180 - val_y2_output_loss: 9.0132 - val_y1_output_root_mean_squared_error: 2.2320 - val_y2_output_root_mean_squared_error: 3.0537
# Epoch 52/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.0689 - y1_output_loss: 3.8042 - y2_output_loss: 9.2994 - y1_output_root_mean_squared_error: 1.9498 - y2_output_root_mean_squared_error: 3.0442 - val_loss: 14.3431 - val_y1_output_loss: 3.3369 - val_y2_output_loss: 10.5057 - val_y1_output_root_mean_squared_error: 1.8601 - val_y2_output_root_mean_squared_error: 3.2990
# Epoch 53/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.9616 - y1_output_loss: 2.2074 - y2_output_loss: 5.8330 - y1_output_root_mean_squared_error: 1.4685 - y2_output_root_mean_squared_error: 2.4094 - val_loss: 15.7839 - val_y1_output_loss: 5.0942 - val_y2_output_loss: 10.6061 - val_y1_output_root_mean_squared_error: 2.2706 - val_y2_output_root_mean_squared_error: 3.2601
# Epoch 54/500
# 614/614 [==============================] - 0s 161us/sample - loss: 6.5619 - y1_output_loss: 2.0280 - y2_output_loss: 4.4857 - y1_output_root_mean_squared_error: 1.4309 - y2_output_root_mean_squared_error: 2.1247 - val_loss: 7.3854 - val_y1_output_loss: 2.1815 - val_y2_output_loss: 5.1722 - val_y1_output_root_mean_squared_error: 1.4851 - val_y2_output_root_mean_squared_error: 2.2760
# Epoch 55/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.1812 - y1_output_loss: 1.4579 - y2_output_loss: 3.6744 - y1_output_root_mean_squared_error: 1.2130 - y2_output_root_mean_squared_error: 1.9261 - val_loss: 5.2268 - val_y1_output_loss: 1.6139 - val_y2_output_loss: 3.5470 - val_y1_output_root_mean_squared_error: 1.2877 - val_y2_output_root_mean_squared_error: 1.8891
# Epoch 56/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.0917 - y1_output_loss: 1.6745 - y2_output_loss: 4.5032 - y1_output_root_mean_squared_error: 1.2915 - y2_output_root_mean_squared_error: 2.1033 - val_loss: 11.9087 - val_y1_output_loss: 3.8540 - val_y2_output_loss: 7.6283 - val_y1_output_root_mean_squared_error: 2.0002 - val_y2_output_root_mean_squared_error: 2.8121
# Epoch 57/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.6851 - y1_output_loss: 1.7550 - y2_output_loss: 4.8975 - y1_output_root_mean_squared_error: 1.3237 - y2_output_root_mean_squared_error: 2.2210 - val_loss: 5.3850 - val_y1_output_loss: 1.6295 - val_y2_output_loss: 3.6482 - val_y1_output_root_mean_squared_error: 1.2913 - val_y2_output_root_mean_squared_error: 1.9281
# Epoch 58/500
# 614/614 [==============================] - 0s 171us/sample - loss: 6.9005 - y1_output_loss: 1.9768 - y2_output_loss: 5.0077 - y1_output_root_mean_squared_error: 1.3932 - y2_output_root_mean_squared_error: 2.2270 - val_loss: 22.2174 - val_y1_output_loss: 5.5103 - val_y2_output_loss: 16.4105 - val_y1_output_root_mean_squared_error: 2.3692 - val_y2_output_root_mean_squared_error: 4.0749
# Epoch 59/500
# 614/614 [==============================] - 0s 167us/sample - loss: 6.8561 - y1_output_loss: 1.6910 - y2_output_loss: 5.1463 - y1_output_root_mean_squared_error: 1.3042 - y2_output_root_mean_squared_error: 2.2705 - val_loss: 7.9019 - val_y1_output_loss: 1.4467 - val_y2_output_loss: 6.4083 - val_y1_output_root_mean_squared_error: 1.2125 - val_y2_output_root_mean_squared_error: 2.5361
# Epoch 60/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.3906 - y1_output_loss: 1.5415 - y2_output_loss: 3.9068 - y1_output_root_mean_squared_error: 1.2415 - y2_output_root_mean_squared_error: 1.9620 - val_loss: 24.8816 - val_y1_output_loss: 3.7081 - val_y2_output_loss: 20.9595 - val_y1_output_root_mean_squared_error: 1.9351 - val_y2_output_root_mean_squared_error: 4.5975
# Epoch 61/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.8842 - y1_output_loss: 1.6647 - y2_output_loss: 4.1960 - y1_output_root_mean_squared_error: 1.2933 - y2_output_root_mean_squared_error: 2.0522 - val_loss: 4.9661 - val_y1_output_loss: 1.3911 - val_y2_output_loss: 3.4574 - val_y1_output_root_mean_squared_error: 1.1970 - val_y2_output_root_mean_squared_error: 1.8797
# Epoch 62/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.6979 - y1_output_loss: 1.4296 - y2_output_loss: 3.3105 - y1_output_root_mean_squared_error: 1.1836 - y2_output_root_mean_squared_error: 1.8158 - val_loss: 13.4477 - val_y1_output_loss: 4.3900 - val_y2_output_loss: 8.5885 - val_y1_output_root_mean_squared_error: 2.1316 - val_y2_output_root_mean_squared_error: 2.9839
# Epoch 63/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.0114 - y1_output_loss: 1.3816 - y2_output_loss: 3.6358 - y1_output_root_mean_squared_error: 1.1787 - y2_output_root_mean_squared_error: 1.9032 - val_loss: 12.7977 - val_y1_output_loss: 4.8594 - val_y2_output_loss: 7.5002 - val_y1_output_root_mean_squared_error: 2.2465 - val_y2_output_root_mean_squared_error: 2.7840
# Epoch 64/500
# 614/614 [==============================] - 0s 141us/sample - loss: 8.1715 - y1_output_loss: 2.3146 - y2_output_loss: 5.9296 - y1_output_root_mean_squared_error: 1.5197 - y2_output_root_mean_squared_error: 2.4211 - val_loss: 13.2574 - val_y1_output_loss: 2.7804 - val_y2_output_loss: 10.0218 - val_y1_output_root_mean_squared_error: 1.6980 - val_y2_output_root_mean_squared_error: 3.2209
# Epoch 65/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.6769 - y1_output_loss: 1.5767 - y2_output_loss: 4.0711 - y1_output_root_mean_squared_error: 1.2594 - y2_output_root_mean_squared_error: 2.0226 - val_loss: 6.8939 - val_y1_output_loss: 1.4236 - val_y2_output_loss: 5.2459 - val_y1_output_root_mean_squared_error: 1.2073 - val_y2_output_root_mean_squared_error: 2.3316
# Epoch 66/500
# 614/614 [==============================] - 0s 156us/sample - loss: 6.0833 - y1_output_loss: 1.5661 - y2_output_loss: 4.4698 - y1_output_root_mean_squared_error: 1.2563 - y2_output_root_mean_squared_error: 2.1225 - val_loss: 5.9447 - val_y1_output_loss: 1.7163 - val_y2_output_loss: 4.1179 - val_y1_output_root_mean_squared_error: 1.3284 - val_y2_output_root_mean_squared_error: 2.0445
# Epoch 67/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.8802 - y1_output_loss: 1.2486 - y2_output_loss: 3.5964 - y1_output_root_mean_squared_error: 1.1204 - y2_output_root_mean_squared_error: 1.9040 - val_loss: 5.2771 - val_y1_output_loss: 1.5264 - val_y2_output_loss: 3.7286 - val_y1_output_root_mean_squared_error: 1.2334 - val_y2_output_root_mean_squared_error: 1.9380
# Epoch 68/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.1382 - y1_output_loss: 1.0164 - y2_output_loss: 3.1776 - y1_output_root_mean_squared_error: 1.0046 - y2_output_root_mean_squared_error: 1.7689 - val_loss: 10.9291 - val_y1_output_loss: 2.0084 - val_y2_output_loss: 8.8473 - val_y1_output_root_mean_squared_error: 1.4276 - val_y2_output_root_mean_squared_error: 2.9818
# Epoch 69/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.4429 - y1_output_loss: 1.4447 - y2_output_loss: 3.9681 - y1_output_root_mean_squared_error: 1.2066 - y2_output_root_mean_squared_error: 1.9968 - val_loss: 11.2198 - val_y1_output_loss: 2.2471 - val_y2_output_loss: 8.8367 - val_y1_output_root_mean_squared_error: 1.5119 - val_y2_output_root_mean_squared_error: 2.9890
# Epoch 70/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.5487 - y1_output_loss: 1.2825 - y2_output_loss: 3.2830 - y1_output_root_mean_squared_error: 1.1327 - y2_output_root_mean_squared_error: 1.8071 - val_loss: 6.1630 - val_y1_output_loss: 1.7601 - val_y2_output_loss: 4.1957 - val_y1_output_root_mean_squared_error: 1.3511 - val_y2_output_root_mean_squared_error: 2.0827
# Epoch 71/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.3233 - y1_output_loss: 1.0900 - y2_output_loss: 3.2884 - y1_output_root_mean_squared_error: 1.0403 - y2_output_root_mean_squared_error: 1.8003 - val_loss: 15.3479 - val_y1_output_loss: 2.5144 - val_y2_output_loss: 12.5799 - val_y1_output_root_mean_squared_error: 1.6053 - val_y2_output_root_mean_squared_error: 3.5737
# Epoch 72/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.9461 - y1_output_loss: 1.5272 - y2_output_loss: 4.3822 - y1_output_root_mean_squared_error: 1.2373 - y2_output_root_mean_squared_error: 2.1012 - val_loss: 6.4773 - val_y1_output_loss: 2.3597 - val_y2_output_loss: 3.9026 - val_y1_output_root_mean_squared_error: 1.5613 - val_y2_output_root_mean_squared_error: 2.0099
# Epoch 73/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9173 - y1_output_loss: 1.0678 - y2_output_loss: 2.8837 - y1_output_root_mean_squared_error: 1.0365 - y2_output_root_mean_squared_error: 1.6861 - val_loss: 7.6868 - val_y1_output_loss: 1.4229 - val_y2_output_loss: 6.0112 - val_y1_output_root_mean_squared_error: 1.2149 - val_y2_output_root_mean_squared_error: 2.4921
# Epoch 74/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.8162 - y1_output_loss: 0.9084 - y2_output_loss: 2.9108 - y1_output_root_mean_squared_error: 0.9553 - y2_output_root_mean_squared_error: 1.7040 - val_loss: 5.9089 - val_y1_output_loss: 1.1715 - val_y2_output_loss: 4.5346 - val_y1_output_root_mean_squared_error: 1.1023 - val_y2_output_root_mean_squared_error: 2.1665
# Epoch 75/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.1353 - y1_output_loss: 1.0921 - y2_output_loss: 3.0392 - y1_output_root_mean_squared_error: 1.0456 - y2_output_root_mean_squared_error: 1.7441 - val_loss: 8.4603 - val_y1_output_loss: 2.6780 - val_y2_output_loss: 5.5012 - val_y1_output_root_mean_squared_error: 1.6649 - val_y2_output_root_mean_squared_error: 2.3850
# Epoch 76/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.1555 - y1_output_loss: 1.0264 - y2_output_loss: 3.1838 - y1_output_root_mean_squared_error: 1.0026 - y2_output_root_mean_squared_error: 1.7749 - val_loss: 19.9482 - val_y1_output_loss: 7.1424 - val_y2_output_loss: 12.1197 - val_y1_output_root_mean_squared_error: 2.7207 - val_y2_output_root_mean_squared_error: 3.5421
# Epoch 77/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.1290 - y1_output_loss: 1.2083 - y2_output_loss: 3.8807 - y1_output_root_mean_squared_error: 1.1019 - y2_output_root_mean_squared_error: 1.9786 - val_loss: 5.0357 - val_y1_output_loss: 1.3539 - val_y2_output_loss: 3.5219 - val_y1_output_root_mean_squared_error: 1.1833 - val_y2_output_root_mean_squared_error: 1.9067
# Epoch 78/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.9916 - y1_output_loss: 1.1125 - y2_output_loss: 2.8451 - y1_output_root_mean_squared_error: 1.0587 - y2_output_root_mean_squared_error: 1.6943 - val_loss: 4.5877 - val_y1_output_loss: 1.4129 - val_y2_output_loss: 3.0641 - val_y1_output_root_mean_squared_error: 1.1969 - val_y2_output_root_mean_squared_error: 1.7763
# Epoch 79/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.7912 - y1_output_loss: 0.8189 - y2_output_loss: 2.9529 - y1_output_root_mean_squared_error: 0.9077 - y2_output_root_mean_squared_error: 1.7226 - val_loss: 3.1982 - val_y1_output_loss: 0.7604 - val_y2_output_loss: 2.3486 - val_y1_output_root_mean_squared_error: 0.8809 - val_y2_output_root_mean_squared_error: 1.5564
# Epoch 80/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.6317 - y1_output_loss: 0.8224 - y2_output_loss: 2.7874 - y1_output_root_mean_squared_error: 0.9098 - y2_output_root_mean_squared_error: 1.6745 - val_loss: 3.8306 - val_y1_output_loss: 0.9253 - val_y2_output_loss: 2.8217 - val_y1_output_root_mean_squared_error: 0.9740 - val_y2_output_root_mean_squared_error: 1.6976
# Epoch 81/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.0921 - y1_output_loss: 0.7156 - y2_output_loss: 2.3639 - y1_output_root_mean_squared_error: 0.8468 - y2_output_root_mean_squared_error: 1.5411 - val_loss: 7.0988 - val_y1_output_loss: 0.6400 - val_y2_output_loss: 6.3205 - val_y1_output_root_mean_squared_error: 0.8115 - val_y2_output_root_mean_squared_error: 2.5378
# Epoch 82/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.3069 - y1_output_loss: 0.7829 - y2_output_loss: 2.5218 - y1_output_root_mean_squared_error: 0.8769 - y2_output_root_mean_squared_error: 1.5931 - val_loss: 12.6473 - val_y1_output_loss: 4.0816 - val_y2_output_loss: 8.3164 - val_y1_output_root_mean_squared_error: 2.0401 - val_y2_output_root_mean_squared_error: 2.9130
# Epoch 83/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.3594 - y1_output_loss: 0.8467 - y2_output_loss: 2.4955 - y1_output_root_mean_squared_error: 0.9222 - y2_output_root_mean_squared_error: 1.5840 - val_loss: 3.0362 - val_y1_output_loss: 0.7024 - val_y2_output_loss: 2.2476 - val_y1_output_root_mean_squared_error: 0.8524 - val_y2_output_root_mean_squared_error: 1.5198
# Epoch 84/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.1857 - y1_output_loss: 0.6936 - y2_output_loss: 2.4692 - y1_output_root_mean_squared_error: 0.8359 - y2_output_root_mean_squared_error: 1.5770 - val_loss: 4.0280 - val_y1_output_loss: 0.7565 - val_y2_output_loss: 3.2059 - val_y1_output_root_mean_squared_error: 0.8799 - val_y2_output_root_mean_squared_error: 1.8038
# Epoch 85/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8798 - y1_output_loss: 0.6296 - y2_output_loss: 2.2291 - y1_output_root_mean_squared_error: 0.7965 - y2_output_root_mean_squared_error: 1.4985 - val_loss: 4.1421 - val_y1_output_loss: 0.7402 - val_y2_output_loss: 3.3149 - val_y1_output_root_mean_squared_error: 0.8713 - val_y2_output_root_mean_squared_error: 1.8393
# Epoch 86/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.8191 - y1_output_loss: 0.8801 - y2_output_loss: 2.9239 - y1_output_root_mean_squared_error: 0.9422 - y2_output_root_mean_squared_error: 1.7121 - val_loss: 3.5784 - val_y1_output_loss: 0.7227 - val_y2_output_loss: 2.7588 - val_y1_output_root_mean_squared_error: 0.8635 - val_y2_output_root_mean_squared_error: 1.6831
# Epoch 87/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.2471 - y1_output_loss: 1.5273 - y2_output_loss: 3.6909 - y1_output_root_mean_squared_error: 1.2412 - y2_output_root_mean_squared_error: 1.9252 - val_loss: 4.4447 - val_y1_output_loss: 0.7427 - val_y2_output_loss: 3.6461 - val_y1_output_root_mean_squared_error: 0.8653 - val_y2_output_root_mean_squared_error: 1.9225
# Epoch 88/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9367 - y1_output_loss: 0.8846 - y2_output_loss: 3.0455 - y1_output_root_mean_squared_error: 0.9380 - y2_output_root_mean_squared_error: 1.7484 - val_loss: 5.1111 - val_y1_output_loss: 1.7413 - val_y2_output_loss: 3.2199 - val_y1_output_root_mean_squared_error: 1.3361 - val_y2_output_root_mean_squared_error: 1.8237
# Epoch 89/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.7651 - y1_output_loss: 1.5520 - y2_output_loss: 4.1770 - y1_output_root_mean_squared_error: 1.2495 - y2_output_root_mean_squared_error: 2.0504 - val_loss: 3.9255 - val_y1_output_loss: 0.8193 - val_y2_output_loss: 2.9716 - val_y1_output_root_mean_squared_error: 0.9219 - val_y2_output_root_mean_squared_error: 1.7537
# Epoch 90/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.3702 - y1_output_loss: 0.7995 - y2_output_loss: 2.5994 - y1_output_root_mean_squared_error: 0.8958 - y2_output_root_mean_squared_error: 1.6024 - val_loss: 14.8069 - val_y1_output_loss: 1.3316 - val_y2_output_loss: 13.2063 - val_y1_output_root_mean_squared_error: 1.1674 - val_y2_output_root_mean_squared_error: 3.6666
# Epoch 91/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.4781 - y1_output_loss: 1.0495 - y2_output_loss: 3.3950 - y1_output_root_mean_squared_error: 1.0279 - y2_output_root_mean_squared_error: 1.8498 - val_loss: 3.7948 - val_y1_output_loss: 1.3585 - val_y2_output_loss: 2.3526 - val_y1_output_root_mean_squared_error: 1.1798 - val_y2_output_root_mean_squared_error: 1.5502
# Epoch 92/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.0439 - y1_output_loss: 0.7316 - y2_output_loss: 2.2854 - y1_output_root_mean_squared_error: 0.8588 - y2_output_root_mean_squared_error: 1.5187 - val_loss: 2.6038 - val_y1_output_loss: 0.5113 - val_y2_output_loss: 2.0187 - val_y1_output_root_mean_squared_error: 0.7240 - val_y2_output_root_mean_squared_error: 1.4421
# Epoch 93/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.6910 - y1_output_loss: 0.9015 - y2_output_loss: 2.8000 - y1_output_root_mean_squared_error: 0.9484 - y2_output_root_mean_squared_error: 1.6708 - val_loss: 4.3864 - val_y1_output_loss: 0.7143 - val_y2_output_loss: 3.5250 - val_y1_output_root_mean_squared_error: 0.8601 - val_y2_output_root_mean_squared_error: 1.9096
# Epoch 94/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.4066 - y1_output_loss: 0.9336 - y2_output_loss: 2.4419 - y1_output_root_mean_squared_error: 0.9704 - y2_output_root_mean_squared_error: 1.5700 - val_loss: 2.7985 - val_y1_output_loss: 0.7059 - val_y2_output_loss: 2.0051 - val_y1_output_root_mean_squared_error: 0.8550 - val_y2_output_root_mean_squared_error: 1.4379
# Epoch 95/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6213 - y1_output_loss: 0.5810 - y2_output_loss: 2.0483 - y1_output_root_mean_squared_error: 0.7522 - y2_output_root_mean_squared_error: 1.4337 - val_loss: 6.6879 - val_y1_output_loss: 2.8385 - val_y2_output_loss: 3.7176 - val_y1_output_root_mean_squared_error: 1.6998 - val_y2_output_root_mean_squared_error: 1.9490
# Epoch 96/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.6677 - y1_output_loss: 1.0100 - y2_output_loss: 2.6433 - y1_output_root_mean_squared_error: 1.0078 - y2_output_root_mean_squared_error: 1.6285 - val_loss: 4.7097 - val_y1_output_loss: 0.6705 - val_y2_output_loss: 3.9216 - val_y1_output_root_mean_squared_error: 0.8333 - val_y2_output_root_mean_squared_error: 2.0038
# Epoch 97/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6846 - y1_output_loss: 0.5780 - y2_output_loss: 2.0821 - y1_output_root_mean_squared_error: 0.7635 - y2_output_root_mean_squared_error: 1.4497 - val_loss: 2.5577 - val_y1_output_loss: 0.4853 - val_y2_output_loss: 2.0022 - val_y1_output_root_mean_squared_error: 0.7047 - val_y2_output_root_mean_squared_error: 1.4357
# Epoch 98/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.6544 - y1_output_loss: 0.7838 - y2_output_loss: 2.8571 - y1_output_root_mean_squared_error: 0.8888 - y2_output_root_mean_squared_error: 1.6925 - val_loss: 6.4018 - val_y1_output_loss: 0.8017 - val_y2_output_loss: 5.5509 - val_y1_output_root_mean_squared_error: 0.9004 - val_y2_output_root_mean_squared_error: 2.3646
# Epoch 99/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.1393 - y1_output_loss: 0.7567 - y2_output_loss: 2.3689 - y1_output_root_mean_squared_error: 0.8735 - y2_output_root_mean_squared_error: 1.5415 - val_loss: 3.3684 - val_y1_output_loss: 0.6387 - val_y2_output_loss: 2.6632 - val_y1_output_root_mean_squared_error: 0.8119 - val_y2_output_root_mean_squared_error: 1.6460
# Epoch 100/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.9518 - y1_output_loss: 1.1320 - y2_output_loss: 2.8274 - y1_output_root_mean_squared_error: 1.0598 - y2_output_root_mean_squared_error: 1.6819 - val_loss: 8.8521 - val_y1_output_loss: 3.1743 - val_y2_output_loss: 5.5041 - val_y1_output_root_mean_squared_error: 1.7907 - val_y2_output_root_mean_squared_error: 2.3760
# Epoch 101/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.8993 - y1_output_loss: 0.7392 - y2_output_loss: 2.1954 - y1_output_root_mean_squared_error: 0.8612 - y2_output_root_mean_squared_error: 1.4689 - val_loss: 3.6918 - val_y1_output_loss: 0.5911 - val_y2_output_loss: 2.9869 - val_y1_output_root_mean_squared_error: 0.7780 - val_y2_output_root_mean_squared_error: 1.7568
# Epoch 102/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.0829 - y1_output_loss: 0.7148 - y2_output_loss: 2.3665 - y1_output_root_mean_squared_error: 0.8457 - y2_output_root_mean_squared_error: 1.5387 - val_loss: 4.1181 - val_y1_output_loss: 1.0458 - val_y2_output_loss: 2.9253 - val_y1_output_root_mean_squared_error: 1.0413 - val_y2_output_root_mean_squared_error: 1.7418
# Epoch 103/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8710 - y1_output_loss: 0.6605 - y2_output_loss: 2.2316 - y1_output_root_mean_squared_error: 0.8118 - y2_output_root_mean_squared_error: 1.4873 - val_loss: 5.3256 - val_y1_output_loss: 0.7473 - val_y2_output_loss: 4.4649 - val_y1_output_root_mean_squared_error: 0.8690 - val_y2_output_root_mean_squared_error: 2.1378
# Epoch 104/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5907 - y1_output_loss: 0.5906 - y2_output_loss: 2.0110 - y1_output_root_mean_squared_error: 0.7660 - y2_output_root_mean_squared_error: 1.4156 - val_loss: 8.9649 - val_y1_output_loss: 2.9438 - val_y2_output_loss: 5.7313 - val_y1_output_root_mean_squared_error: 1.7420 - val_y2_output_root_mean_squared_error: 2.4353
# Epoch 105/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.9569 - y1_output_loss: 0.9866 - y2_output_loss: 2.9607 - y1_output_root_mean_squared_error: 0.9965 - y2_output_root_mean_squared_error: 1.7216 - val_loss: 3.6971 - val_y1_output_loss: 0.5838 - val_y2_output_loss: 2.9919 - val_y1_output_root_mean_squared_error: 0.7747 - val_y2_output_root_mean_squared_error: 1.7598
# Epoch 106/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.7401 - y1_output_loss: 0.6691 - y2_output_loss: 2.0820 - y1_output_root_mean_squared_error: 0.8211 - y2_output_root_mean_squared_error: 1.4373 - val_loss: 7.9390 - val_y1_output_loss: 0.8627 - val_y2_output_loss: 6.9964 - val_y1_output_root_mean_squared_error: 0.9277 - val_y2_output_root_mean_squared_error: 2.6605
# Epoch 107/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.5249 - y1_output_loss: 0.7712 - y2_output_loss: 2.7443 - y1_output_root_mean_squared_error: 0.8792 - y2_output_root_mean_squared_error: 1.6589 - val_loss: 2.9316 - val_y1_output_loss: 0.5308 - val_y2_output_loss: 2.3215 - val_y1_output_root_mean_squared_error: 0.7402 - val_y2_output_root_mean_squared_error: 1.5440
# Epoch 108/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.1219 - y1_output_loss: 0.8967 - y2_output_loss: 3.2436 - y1_output_root_mean_squared_error: 0.9488 - y2_output_root_mean_squared_error: 1.7949 - val_loss: 3.1085 - val_y1_output_loss: 0.5357 - val_y2_output_loss: 2.5179 - val_y1_output_root_mean_squared_error: 0.7343 - val_y2_output_root_mean_squared_error: 1.6029
# Epoch 109/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.7036 - y1_output_loss: 1.2534 - y2_output_loss: 3.4083 - y1_output_root_mean_squared_error: 1.1248 - y2_output_root_mean_squared_error: 1.8543 - val_loss: 4.1151 - val_y1_output_loss: 1.2328 - val_y2_output_loss: 2.7608 - val_y1_output_root_mean_squared_error: 1.1262 - val_y2_output_root_mean_squared_error: 1.6872
# Epoch 110/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.6845 - y1_output_loss: 0.5758 - y2_output_loss: 2.0839 - y1_output_root_mean_squared_error: 0.7623 - y2_output_root_mean_squared_error: 1.4503 - val_loss: 2.6733 - val_y1_output_loss: 0.5563 - val_y2_output_loss: 2.0424 - val_y1_output_root_mean_squared_error: 0.7578 - val_y2_output_root_mean_squared_error: 1.4488
# Epoch 111/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.4071 - y1_output_loss: 0.5678 - y2_output_loss: 1.8477 - y1_output_root_mean_squared_error: 0.7544 - y2_output_root_mean_squared_error: 1.3557 - val_loss: 5.1135 - val_y1_output_loss: 0.7609 - val_y2_output_loss: 4.2424 - val_y1_output_root_mean_squared_error: 0.8829 - val_y2_output_root_mean_squared_error: 2.0818
# Epoch 112/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.7386 - y1_output_loss: 0.8418 - y2_output_loss: 2.8630 - y1_output_root_mean_squared_error: 0.9209 - y2_output_root_mean_squared_error: 1.7002 - val_loss: 2.4808 - val_y1_output_loss: 0.4991 - val_y2_output_loss: 1.9018 - val_y1_output_root_mean_squared_error: 0.7180 - val_y2_output_root_mean_squared_error: 1.4019
# Epoch 113/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.7438 - y1_output_loss: 0.5806 - y2_output_loss: 2.1391 - y1_output_root_mean_squared_error: 0.7650 - y2_output_root_mean_squared_error: 1.4692 - val_loss: 3.2251 - val_y1_output_loss: 0.7458 - val_y2_output_loss: 2.3640 - val_y1_output_root_mean_squared_error: 0.8790 - val_y2_output_root_mean_squared_error: 1.5661
# Epoch 114/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.7394 - y1_output_loss: 1.0956 - y2_output_loss: 2.6139 - y1_output_root_mean_squared_error: 1.0497 - y2_output_root_mean_squared_error: 1.6241 - val_loss: 2.9989 - val_y1_output_loss: 0.5414 - val_y2_output_loss: 2.3788 - val_y1_output_root_mean_squared_error: 0.7432 - val_y2_output_root_mean_squared_error: 1.5641
# Epoch 115/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9056 - y1_output_loss: 0.6685 - y2_output_loss: 2.2290 - y1_output_root_mean_squared_error: 0.8204 - y2_output_root_mean_squared_error: 1.4942 - val_loss: 2.6219 - val_y1_output_loss: 0.5143 - val_y2_output_loss: 2.0311 - val_y1_output_root_mean_squared_error: 0.7285 - val_y2_output_root_mean_squared_error: 1.4461
# Epoch 116/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.5673 - y1_output_loss: 1.6116 - y2_output_loss: 4.9457 - y1_output_root_mean_squared_error: 1.2746 - y2_output_root_mean_squared_error: 2.2232 - val_loss: 5.8089 - val_y1_output_loss: 0.9327 - val_y2_output_loss: 4.7507 - val_y1_output_root_mean_squared_error: 0.9792 - val_y2_output_root_mean_squared_error: 2.2023
# Epoch 117/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5400 - y1_output_loss: 0.5458 - y2_output_loss: 1.9871 - y1_output_root_mean_squared_error: 0.7419 - y2_output_root_mean_squared_error: 1.4105 - val_loss: 5.0944 - val_y1_output_loss: 0.7118 - val_y2_output_loss: 4.2607 - val_y1_output_root_mean_squared_error: 0.8568 - val_y2_output_root_mean_squared_error: 2.0881
# Epoch 118/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7053 - y1_output_loss: 0.6381 - y2_output_loss: 2.0630 - y1_output_root_mean_squared_error: 0.8020 - y2_output_root_mean_squared_error: 1.4360 - val_loss: 3.8945 - val_y1_output_loss: 0.6849 - val_y2_output_loss: 3.0779 - val_y1_output_root_mean_squared_error: 0.8397 - val_y2_output_root_mean_squared_error: 1.7859
# Epoch 119/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.2558 - y1_output_loss: 0.4375 - y2_output_loss: 1.8101 - y1_output_root_mean_squared_error: 0.6601 - y2_output_root_mean_squared_error: 1.3491 - val_loss: 3.9771 - val_y1_output_loss: 0.7299 - val_y2_output_loss: 3.1199 - val_y1_output_root_mean_squared_error: 0.8673 - val_y2_output_root_mean_squared_error: 1.7958
# Epoch 120/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.2036 - y1_output_loss: 0.7407 - y2_output_loss: 2.4369 - y1_output_root_mean_squared_error: 0.8640 - y2_output_root_mean_squared_error: 1.5675 - val_loss: 3.7448 - val_y1_output_loss: 1.1679 - val_y2_output_loss: 2.4456 - val_y1_output_root_mean_squared_error: 1.1009 - val_y2_output_root_mean_squared_error: 1.5915
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4708 - y1_output_loss: 0.1337 - y2_output_loss: 0.3356 - y1_output_root_mean_squared_error: 0.3653 - y2_output_root_mean_squared_error: 0.5808 - val_loss: 1.1423 - val_y1_output_loss: 0.1465 - val_y2_output_loss: 0.9663 - val_y1_output_root_mean_squared_error: 0.3887 - val_y2_output_root_mean_squared_error: 0.9956
# Epoch 462/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4261 - y1_output_loss: 0.1293 - y2_output_loss: 0.2936 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5437 - val_loss: 1.1488 - val_y1_output_loss: 0.2183 - val_y2_output_loss: 0.8992 - val_y1_output_root_mean_squared_error: 0.4724 - val_y2_output_root_mean_squared_error: 0.9621
# Epoch 463/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5144 - y1_output_loss: 0.1521 - y2_output_loss: 0.3596 - y1_output_root_mean_squared_error: 0.3918 - y2_output_root_mean_squared_error: 0.6008 - val_loss: 1.0537 - val_y1_output_loss: 0.1546 - val_y2_output_loss: 0.8771 - val_y1_output_root_mean_squared_error: 0.3967 - val_y2_output_root_mean_squared_error: 0.9467
# Epoch 464/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6934 - y1_output_loss: 0.2272 - y2_output_loss: 0.4620 - y1_output_root_mean_squared_error: 0.4783 - y2_output_root_mean_squared_error: 0.6816 - val_loss: 1.0415 - val_y1_output_loss: 0.1592 - val_y2_output_loss: 0.8546 - val_y1_output_root_mean_squared_error: 0.4057 - val_y2_output_root_mean_squared_error: 0.9364
# Epoch 465/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4457 - y1_output_loss: 0.1238 - y2_output_loss: 0.3290 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.5664 - val_loss: 2.1895 - val_y1_output_loss: 0.2416 - val_y2_output_loss: 1.8872 - val_y1_output_root_mean_squared_error: 0.4997 - val_y2_output_root_mean_squared_error: 1.3928
# Epoch 466/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5626 - y1_output_loss: 0.1564 - y2_output_loss: 0.4105 - y1_output_root_mean_squared_error: 0.3858 - y2_output_root_mean_squared_error: 0.6432 - val_loss: 1.0381 - val_y1_output_loss: 0.1904 - val_y2_output_loss: 0.8205 - val_y1_output_root_mean_squared_error: 0.4422 - val_y2_output_root_mean_squared_error: 0.9179
# Epoch 467/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4127 - y1_output_loss: 0.1303 - y2_output_loss: 0.2813 - y1_output_root_mean_squared_error: 0.3600 - y2_output_root_mean_squared_error: 0.5320 - val_loss: 1.0881 - val_y1_output_loss: 0.2340 - val_y2_output_loss: 0.8318 - val_y1_output_root_mean_squared_error: 0.4859 - val_y2_output_root_mean_squared_error: 0.9230
# Epoch 468/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4193 - y1_output_loss: 0.1320 - y2_output_loss: 0.2836 - y1_output_root_mean_squared_error: 0.3647 - y2_output_root_mean_squared_error: 0.5351 - val_loss: 0.9438 - val_y1_output_loss: 0.1822 - val_y2_output_loss: 0.7387 - val_y1_output_root_mean_squared_error: 0.4301 - val_y2_output_root_mean_squared_error: 0.8711
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3778 - y1_output_loss: 0.1166 - y2_output_loss: 0.2630 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.5109 - val_loss: 1.2294 - val_y1_output_loss: 0.1607 - val_y2_output_loss: 1.0417 - val_y1_output_root_mean_squared_error: 0.4048 - val_y2_output_root_mean_squared_error: 1.0322
# Epoch 470/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4327 - y1_output_loss: 0.1431 - y2_output_loss: 0.2869 - y1_output_root_mean_squared_error: 0.3797 - y2_output_root_mean_squared_error: 0.5371 - val_loss: 1.0304 - val_y1_output_loss: 0.1695 - val_y2_output_loss: 0.8351 - val_y1_output_root_mean_squared_error: 0.4169 - val_y2_output_root_mean_squared_error: 0.9255
# Epoch 471/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3365 - y1_output_loss: 0.1264 - y2_output_loss: 0.2267 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.4654 - val_loss: 7.4082 - val_y1_output_loss: 1.2701 - val_y2_output_loss: 5.9352 - val_y1_output_root_mean_squared_error: 1.1476 - val_y2_output_root_mean_squared_error: 2.4680
# Epoch 472/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5329 - y1_output_loss: 0.1554 - y2_output_loss: 0.3731 - y1_output_root_mean_squared_error: 0.3959 - y2_output_root_mean_squared_error: 0.6133 - val_loss: 1.0321 - val_y1_output_loss: 0.1720 - val_y2_output_loss: 0.8405 - val_y1_output_root_mean_squared_error: 0.4176 - val_y2_output_root_mean_squared_error: 0.9261
# Epoch 473/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4646 - y1_output_loss: 0.1372 - y2_output_loss: 0.3289 - y1_output_root_mean_squared_error: 0.3686 - y2_output_root_mean_squared_error: 0.5733 - val_loss: 1.0442 - val_y1_output_loss: 0.1641 - val_y2_output_loss: 0.8533 - val_y1_output_root_mean_squared_error: 0.4114 - val_y2_output_root_mean_squared_error: 0.9354
# Epoch 474/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3964 - y1_output_loss: 0.1218 - y2_output_loss: 0.2722 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.5234 - val_loss: 1.1486 - val_y1_output_loss: 0.2003 - val_y2_output_loss: 0.9147 - val_y1_output_root_mean_squared_error: 0.4553 - val_y2_output_root_mean_squared_error: 0.9702
# Epoch 475/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4967 - y1_output_loss: 0.1388 - y2_output_loss: 0.3588 - y1_output_root_mean_squared_error: 0.3729 - y2_output_root_mean_squared_error: 0.5981 - val_loss: 1.4752 - val_y1_output_loss: 0.4250 - val_y2_output_loss: 1.0248 - val_y1_output_root_mean_squared_error: 0.6610 - val_y2_output_root_mean_squared_error: 1.0190
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 1.7627 - y1_output_loss: 0.5322 - y2_output_loss: 1.4316 - y1_output_root_mean_squared_error: 0.7082 - y2_output_root_mean_squared_error: 1.1230 - val_loss: 20.8387 - val_y1_output_loss: 2.5172 - val_y2_output_loss: 18.2739 - val_y1_output_root_mean_squared_error: 1.5954 - val_y2_output_root_mean_squared_error: 4.2771
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5313 - y1_output_loss: 0.6793 - y2_output_loss: 1.8281 - y1_output_root_mean_squared_error: 0.8281 - y2_output_root_mean_squared_error: 1.3585 - val_loss: 1.1377 - val_y1_output_loss: 0.1495 - val_y2_output_loss: 0.9602 - val_y1_output_root_mean_squared_error: 0.3897 - val_y2_output_root_mean_squared_error: 0.9929
# Epoch 478/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4505 - y1_output_loss: 0.1405 - y2_output_loss: 0.3062 - y1_output_root_mean_squared_error: 0.3761 - y2_output_root_mean_squared_error: 0.5559 - val_loss: 0.9580 - val_y1_output_loss: 0.1485 - val_y2_output_loss: 0.7800 - val_y1_output_root_mean_squared_error: 0.3895 - val_y2_output_root_mean_squared_error: 0.8979
# Epoch 479/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4136 - y1_output_loss: 0.1273 - y2_output_loss: 0.2875 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5344 - val_loss: 1.0328 - val_y1_output_loss: 0.1596 - val_y2_output_loss: 0.8492 - val_y1_output_root_mean_squared_error: 0.4033 - val_y2_output_root_mean_squared_error: 0.9328
# Epoch 480/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4873 - y1_output_loss: 0.1391 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3743 - y2_output_root_mean_squared_error: 0.5893 - val_loss: 1.0368 - val_y1_output_loss: 0.1680 - val_y2_output_loss: 0.8443 - val_y1_output_root_mean_squared_error: 0.4151 - val_y2_output_root_mean_squared_error: 0.9298
# Epoch 481/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3483 - y1_output_loss: 0.1195 - y2_output_loss: 0.2264 - y1_output_root_mean_squared_error: 0.3464 - y2_output_root_mean_squared_error: 0.4778 - val_loss: 0.9673 - val_y1_output_loss: 0.1526 - val_y2_output_loss: 0.7914 - val_y1_output_root_mean_squared_error: 0.3938 - val_y2_output_root_mean_squared_error: 0.9012
# Epoch 482/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5644 - y1_output_loss: 0.1621 - y2_output_loss: 0.3971 - y1_output_root_mean_squared_error: 0.4044 - y2_output_root_mean_squared_error: 0.6331 - val_loss: 1.1552 - val_y1_output_loss: 0.2312 - val_y2_output_loss: 0.8925 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.9580
# Epoch 483/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3644 - y1_output_loss: 0.1262 - y2_output_loss: 0.2355 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.4873 - val_loss: 0.9074 - val_y1_output_loss: 0.1499 - val_y2_output_loss: 0.7314 - val_y1_output_root_mean_squared_error: 0.3930 - val_y2_output_root_mean_squared_error: 0.8678
# Epoch 484/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4018 - y1_output_loss: 0.1304 - y2_output_loss: 0.2684 - y1_output_root_mean_squared_error: 0.3624 - y2_output_root_mean_squared_error: 0.5200 - val_loss: 0.9935 - val_y1_output_loss: 0.1682 - val_y2_output_loss: 0.8035 - val_y1_output_root_mean_squared_error: 0.4152 - val_y2_output_root_mean_squared_error: 0.9062
# Epoch 485/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3571 - y1_output_loss: 0.1163 - y2_output_loss: 0.2467 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.4921 - val_loss: 1.8403 - val_y1_output_loss: 0.1974 - val_y2_output_loss: 1.6010 - val_y1_output_root_mean_squared_error: 0.4496 - val_y2_output_root_mean_squared_error: 1.2799
# Epoch 486/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4504 - y1_output_loss: 0.1497 - y2_output_loss: 0.3075 - y1_output_root_mean_squared_error: 0.3870 - y2_output_root_mean_squared_error: 0.5483 - val_loss: 2.8218 - val_y1_output_loss: 0.2852 - val_y2_output_loss: 2.4763 - val_y1_output_root_mean_squared_error: 0.5381 - val_y2_output_root_mean_squared_error: 1.5913
# Epoch 487/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5917 - y1_output_loss: 0.1535 - y2_output_loss: 0.4340 - y1_output_root_mean_squared_error: 0.3936 - y2_output_root_mean_squared_error: 0.6609 - val_loss: 0.9684 - val_y1_output_loss: 0.1551 - val_y2_output_loss: 0.7891 - val_y1_output_root_mean_squared_error: 0.3983 - val_y2_output_root_mean_squared_error: 0.8999
# Epoch 488/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3977 - y1_output_loss: 0.1165 - y2_output_loss: 0.2781 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.5295 - val_loss: 0.9009 - val_y1_output_loss: 0.1510 - val_y2_output_loss: 0.7243 - val_y1_output_root_mean_squared_error: 0.3934 - val_y2_output_root_mean_squared_error: 0.8638
# Epoch 489/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4714 - y1_output_loss: 0.1486 - y2_output_loss: 0.3225 - y1_output_root_mean_squared_error: 0.3851 - y2_output_root_mean_squared_error: 0.5684 - val_loss: 1.2029 - val_y1_output_loss: 0.1590 - val_y2_output_loss: 1.0118 - val_y1_output_root_mean_squared_error: 0.4044 - val_y2_output_root_mean_squared_error: 1.0195
# Epoch 490/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4228 - y1_output_loss: 0.1131 - y2_output_loss: 0.3058 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.5556 - val_loss: 1.2428 - val_y1_output_loss: 0.1796 - val_y2_output_loss: 1.0220 - val_y1_output_root_mean_squared_error: 0.4296 - val_y2_output_root_mean_squared_error: 1.0287
# Epoch 491/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4947 - y1_output_loss: 0.1252 - y2_output_loss: 0.3666 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.6071 - val_loss: 1.0006 - val_y1_output_loss: 0.1581 - val_y2_output_loss: 0.8207 - val_y1_output_root_mean_squared_error: 0.4026 - val_y2_output_root_mean_squared_error: 0.9157
# Epoch 492/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4562 - y1_output_loss: 0.1262 - y2_output_loss: 0.3289 - y1_output_root_mean_squared_error: 0.3568 - y2_output_root_mean_squared_error: 0.5735 - val_loss: 0.9246 - val_y1_output_loss: 0.1407 - val_y2_output_loss: 0.7610 - val_y1_output_root_mean_squared_error: 0.3803 - val_y2_output_root_mean_squared_error: 0.8832
# Epoch 493/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3788 - y1_output_loss: 0.1235 - y2_output_loss: 0.2529 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.5046 - val_loss: 1.0265 - val_y1_output_loss: 0.1421 - val_y2_output_loss: 0.8523 - val_y1_output_root_mean_squared_error: 0.3826 - val_y2_output_root_mean_squared_error: 0.9382
# Epoch 494/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5069 - y1_output_loss: 0.1264 - y2_output_loss: 0.3771 - y1_output_root_mean_squared_error: 0.3562 - y2_output_root_mean_squared_error: 0.6164 - val_loss: 0.9578 - val_y1_output_loss: 0.1531 - val_y2_output_loss: 0.7811 - val_y1_output_root_mean_squared_error: 0.3953 - val_y2_output_root_mean_squared_error: 0.8953
# Epoch 495/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3355 - y1_output_loss: 0.1214 - y2_output_loss: 0.2130 - y1_output_root_mean_squared_error: 0.3496 - y2_output_root_mean_squared_error: 0.4618 - val_loss: 1.0994 - val_y1_output_loss: 0.1481 - val_y2_output_loss: 0.9301 - val_y1_output_root_mean_squared_error: 0.3892 - val_y2_output_root_mean_squared_error: 0.9736
# Epoch 496/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4180 - y1_output_loss: 0.1289 - y2_output_loss: 0.2863 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.5369 - val_loss: 0.9102 - val_y1_output_loss: 0.1553 - val_y2_output_loss: 0.7318 - val_y1_output_root_mean_squared_error: 0.3969 - val_y2_output_root_mean_squared_error: 0.8676
# Epoch 497/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3861 - y1_output_loss: 0.1197 - y2_output_loss: 0.2645 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.5165 - val_loss: 0.9896 - val_y1_output_loss: 0.1646 - val_y2_output_loss: 0.7975 - val_y1_output_root_mean_squared_error: 0.4111 - val_y2_output_root_mean_squared_error: 0.9059
# Epoch 498/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4728 - y1_output_loss: 0.1358 - y2_output_loss: 0.3404 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.5819 - val_loss: 1.6757 - val_y1_output_loss: 0.2923 - val_y2_output_loss: 1.3485 - val_y1_output_root_mean_squared_error: 0.5424 - val_y2_output_root_mean_squared_error: 1.1754
# Epoch 499/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5729 - y1_output_loss: 0.1415 - y2_output_loss: 0.4290 - y1_output_root_mean_squared_error: 0.3764 - y2_output_root_mean_squared_error: 0.6567 - val_loss: 1.1403 - val_y1_output_loss: 0.2050 - val_y2_output_loss: 0.9085 - val_y1_output_root_mean_squared_error: 0.4581 - val_y2_output_root_mean_squared_error: 0.9646
# Epoch 500/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3780 - y1_output_loss: 0.1223 - y2_output_loss: 0.2537 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5046 - val_loss: 1.0396 - val_y1_output_loss: 0.1330 - val_y2_output_loss: 0.8776 - val_y1_output_root_mean_squared_error: 0.3696 - val_y2_output_root_mean_squared_error: 0.9503

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 1.0396 - y1_output_loss: 0.1356 - y2_output_loss: 0.9119 - y1_output_root_mean_squared_error: 0.3696 - y2_output_root_mean_squared_error: 0.9503
# Loss = 1.0396455882431626, Y1_loss = 0.13560734689235687, Y1_mse = 0.36958155035972595, Y2_loss = 0.9119291305541992, Y2_mse = 0.9502921104431152

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
